# %%
# !pip install requests beautiful-soup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# ERROR: Could not find a version that satisfies the requirement beautiful-soup4 (from versions: none)
# ERROR: No matching distribution found for beautiful-soup4

# %%
import requests
from bs4 import BeautifulSoup
import os

class Crawler:
    def __init__(self):
        self.session = requests.Session()

    def get_soup(self, url):
        try:
            response = self.session.get(url, timeout=10)
            if response.status_code == 200:
                html = response.content
                # Save to a file
                filename = url.replace('https://', '').replace('http://', '').replace('/', '_') + '.html'
                if not os.path.exists('downloaded_pages'):
                    os.makedirs('downloaded_pages')
                with open(os.path.join('downloaded_pages', filename), 'wb') as f:
                    f.write(html)
                return BeautifulSoup(html, 'html.parser')
            elif response.status_code == 301:
                print(f'Redirected: {response.url}')
                return None
            elif response.status_code == 403:
                print('Forbidden')
                return None
            elif response.status_code == 404:
                print('Not Found')
                return None
            elif response.status_code == 500:
                print('Internal Server Error')
                return None
            else:
                print(f'Unexpected HTTP response: {response.status_code}')
                return None
        except requests.exceptions.RequestException as e:
            print(f'RequestException: {str(e)}')
            return None

    def crawl(self, url, max_depth=3):
        if max_depth < 0:
            return
        print(f'Depth: {max_depth} - Visiting: {url}')
        soup = self.get_soup(url)
        if soup is None:
            print("Failed to get page")
            return
        for link in soup.find_all('a'):
            href = link.get('href')
            if href and href.startswith('http'):
                self.crawl(href, max_depth-1)

if __name__ == "__main__":
    crawler = Crawler()
    crawler.crawl("https://example.com", 2)
# Out:
# Depth: 2 - Visiting: https://example.com
# Depth: 1 - Visiting: https://www.iana.org/domains/example
# Depth: 0 - Visiting: http://www.icann.org/topics/idn/
# Depth: 0 - Visiting: http://www.icann.org/
# Depth: 0 - Visiting: http://www.icann.org/en/registries/agreements.htm
# Depth: 0 - Visiting: http://pti.icann.org
# Depth: 0 - Visiting: http://www.icann.org/
# Depth: 0 - Visiting: https://www.icann.org/privacy/policy
# Depth: 0 - Visiting: https://www.icann.org/privacy/tos

# %%
#Crawl the Wikipedia
crawler = Crawler()
crawler.crawl("https://en.wikipedia.org/wiki/Main_Page", 3)
# Out:
# Depth: 3 - Visiting: https://en.wikipedia.org/wiki/Main_Page
# Depth: 2 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# Depth: 1 - Visiting: https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=Tax_deductibility&basic=true&language=en
# Depth: 0 - Visiting: https://donate.wikimedia.org/?uselang=en&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Tax_deductibility
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/501(c)_organization#501(c)(3)
# Depth: 0 - Visiting: https://www.FloridaConsumerHelp.com
# Depth: 0 - Visiting: https://www.state.nj.us/lps/ca/charfrm.htm
# Depth: 0 - Visiting: https://www.charitiesnys.com
# Depth: 0 - Visiting: https://www.sos.wa.gov/charities/
# Depth: 0 - Visiting: https://www.canada.ca/en/department-finance/programs/tax-policy/tax-treaties/country/united-states-america-convention-consolidated-1980-1983-1984-1995-1997-2007.html
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/press/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Bylaws
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/values/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Wikimedia_Foundation_Annual_Plan
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Strategy/Wikimedia_movement/2018-20
# Depth: 0 - Visiting: https://wikimediafoundation.org/role/board/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Non-discrimination_policy
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Pluralism,_internationalism,_and_diversity_policy
# Depth: 0 - Visiting: https://wikimediafoundation.org/role/staff-contractors/
# Depth: 0 - Visiting: https://annual.wikimedia.org
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/financial-reports/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Wikimedia_chapters
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Tax_deductibility&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page_end&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Tax_deductibility&oldid=35992
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Home
# Depth: 0 - Visiting: https://collab.wikimedia.org/wiki/Fundraising/Donatewiki_documentation
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:Privacy_policy
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:About
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:General_disclaimer
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/donate.wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Cookie_statement
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://foundation.wikimedia.org/wiki/Special:LandingCheck?landing_page=Donor_privacy_policy&basic=true&language=en
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://wikimediafoundation.org/news/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Answers
# Depth: 0 - Visiting: https://wikimediafoundation.org/participate/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/values/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/financial-reports/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Fundraising/Reports
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Contents
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_Foundation
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Access_to_nonpublic_information_policy
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Code_of_Conduct
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Office_actions
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Fundraising_principles
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Legal/Legal_Policies
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Template:Policies_navbox&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates/Portal
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_chapters
# Depth: 0 - Visiting: https://lists.wikimedia.org/postorius/lists/wikimediaannounce-l.lists.wikimedia.org/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Data_retention_guidelines
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates/Models
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_local_chapters
# Depth: 0 - Visiting: https://wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Donor_privacy_policy/en&oldid=122990
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Donor_privacy_policy/en&oldid=122670
# Depth: 0 - Visiting: https://wikimediafoundation.org/w/index.php?title=Donor_policy/en&oldid=94164
# Depth: 0 - Visiting: https://wikimediafoundation.org/w/index.php?title=Donor_policy&oldid=62924
# Depth: 0 - Visiting: https://wikimediafoundation.org/w/index.php?title=Donor_privacy_policy&oldid=60022
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Template:Privacy_policy_navigation_2&action=edit
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Special:Translate/page-Template:Privacy_policy_navigation_2&language=en&action=page
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Access_to_nonpublic_personal_data_policy/Noticeboard
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Policy:Donor_privacy_policy/en&oldid=240961
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/foundation.wikimedia.org
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://foundation.wikimedia.org/wiki/Special:LandingCheck?landing_page=Donor_privacy_policy&basic=true&language=en
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://wikimediafoundation.org/news/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Answers
# Depth: 0 - Visiting: https://wikimediafoundation.org/participate/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/values/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/financial-reports/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Fundraising/Reports
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Contents
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_Foundation
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Access_to_nonpublic_information_policy
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Code_of_Conduct
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Office_actions
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Fundraising_principles
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Legal/Legal_Policies
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Template:Policies_navbox&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates/Portal
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_chapters
# Depth: 0 - Visiting: https://lists.wikimedia.org/postorius/lists/wikimediaannounce-l.lists.wikimedia.org/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Data_retention_guidelines
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates/Models
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_local_chapters
# Depth: 0 - Visiting: https://wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Donor_privacy_policy/en&oldid=122990
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Donor_privacy_policy/en&oldid=122670
# Depth: 0 - Visiting: https://wikimediafoundation.org/w/index.php?title=Donor_policy/en&oldid=94164
# Depth: 0 - Visiting: https://wikimediafoundation.org/w/index.php?title=Donor_policy&oldid=62924
# Depth: 0 - Visiting: https://wikimediafoundation.org/w/index.php?title=Donor_privacy_policy&oldid=60022
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Template:Privacy_policy_navigation_2&action=edit
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Special:Translate/page-Template:Privacy_policy_navigation_2&language=en&action=page
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Access_to_nonpublic_personal_data_policy/Noticeboard
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Policy:Donor_privacy_policy/en&oldid=240961
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/foundation.wikimedia.org
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=Problems_donating&basic=true&language=en
# Depth: 0 - Visiting: https://donate.wikimedia.org/?uselang=en&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Problems_donating
# Depth: 0 - Visiting: https://www.paypal.com/cgi-bin/helpscr?cmd=_help&t=escalateTab
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/Zendesk
# Depth: 0 - Visiting: https://www.zendesk.com/company/customers-partners/privacy-policy/
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.zendesk.com/company/customers-partners/master-subscription-agreement/#region-specific-terms
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Problems_donating&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page_end&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Problems_donating&oldid=38127
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Home
# Depth: 0 - Visiting: https://collab.wikimedia.org/wiki/Fundraising/Donatewiki_documentation
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:Privacy_policy
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:About
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:General_disclaimer
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/donate.wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Cookie_statement
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=Ways_to_Give&basic=true&language=en
# Depth: 0 - Visiting: https://donate.wikimedia.org/?uselang=en&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Ways_to_Give
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=DZ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AO
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BI
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TD
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=EG
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GH
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=KE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LR
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NG
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=ZA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=UG
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AZ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BH
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BD
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=KH
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=HK
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=IN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=IL
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=JP
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=JO
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=KZ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=KW
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MO
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MY
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MV
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NP
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=OM
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PK
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PH
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=QA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=SG
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LK
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TW
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TJ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TH
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TL
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=VN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AL
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AD
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BG
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=HR
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CY
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CZ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=DK
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=EE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=FR
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=DE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GR
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=HU
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=IS
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=IE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=IT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LV
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LI
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LU
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MC
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=ME
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NL
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NO
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PL
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=RO
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=RS
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=SK
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=SI
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=ES
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=SE
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CH
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=UA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GB
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=VA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AW
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BS
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BB
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BZ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BM
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CR
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=DM
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GD
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GP
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=HT
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=HN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=JM
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MQ
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MX
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NI
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PA
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PR
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=KN
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=LC
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PM
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=VC
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TT
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=TC
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=US
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AR
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BO
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=BR
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CL
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CO
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=EC
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=FK
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GF
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GY
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PY
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PE
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=SR
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=UY
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=VE
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AS
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=AU
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=CK
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=FJ
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PF
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=GU
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=KI
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=MH
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=FM
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NR
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=NZ
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserLandingPage?utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en&country=PW
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?monthly=true&utm_medium=Waystogive&utm_source=Waystogive&utm_campaign=C11_Waystogive&uselang=en
# Unexpected HTTP response: 429
# Failed to get page
# Depth: 0 - Visiting: https://www.dafdirect.org/DAFDirect/daflink?_dafdirect_settings=200049703_2111_37e668cf-3ab5-4c94-a71a-5d1d3dcaed65&designatedText=&amountValue=
# Depth: 0 - Visiting: https://www.vanguardcharitable.org/
# Depth: 0 - Visiting: https://aef.donorcentral.com/
# Depth: 0 - Visiting: https://www.jewishfed.org/
# Depth: 0 - Visiting: https://www.siliconvalleycf.org/
# Depth: 0 - Visiting: https://www.nycommunitytrust.org/
# Depth: 0 - Visiting: https://www.trowepricecharitable.org/
# Depth: 0 - Visiting: https://www.franklintempleton.com/investor/investments-and-solutions/solutions/charitable-giving/
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://wikimediaendowment.org/
# Depth: 0 - Visiting: https://donate.wikimedia.org/?uselang=en&utm_medium=endowment&utm_campaign=C11_Waystogive&utm_source=Waystogive
# Depth: 0 - Visiting: https://wikimediaendowment.org/
# Depth: 0 - Visiting: https://www.freewill.com/qcd/wikipedia?utm_source=Waystogive
# Depth: 0 - Visiting: https://www.freewill.com/wikipedia?utm_source=Waystogive
# Depth: 0 - Visiting: https://wikimediaendowment.org/
# Depth: 0 - Visiting: https://www.matchinggifts.com/wikimedia_iframe
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Volunteer_Hour_Match
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Ways_to_Give&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page_end&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Ways_to_Give&oldid=38312
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Home
# Depth: 0 - Visiting: https://collab.wikimedia.org/wiki/Fundraising/Donatewiki_documentation
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:Privacy_policy
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:About
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:General_disclaimer
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/donate.wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Cookie_statement
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=FAQ&basic=true&language=en
# Depth: 0 - Visiting: https://donate.wikimedia.org/?uselang=en&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=FAQ
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Answers
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://www.wikipedia.org
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/Wikipedia:Vandalism
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/
# Depth: 0 - Visiting: https://commons.wikimedia.org/wiki/
# Depth: 0 - Visiting: https://en.wiktionary.org/wiki/
# Depth: 0 - Visiting: https://en.wikiquote.org/wiki/
# Depth: 0 - Visiting: https://en.wikibooks.org/wiki/
# Depth: 0 - Visiting: https://en.wikisource.org/wiki/
# Depth: 0 - Visiting: https://species.wikimedia.org/wiki/
# Depth: 0 - Visiting: https://en.wikinews.org/wiki/
# Depth: 0 - Visiting: https://en.wikiversity.org/wiki/
# Depth: 0 - Visiting: https://www.wikidata.org/wiki/
# Depth: 0 - Visiting: https://en.wikivoyage.org/wiki/
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/WikiLeaks
# Depth: 0 - Visiting: https://donate.wikimedia.org/?uselang=en&utm_medium=donatewiki_page&utm_campaign=donate_link&utm_source=FAQ
# Depth: 0 - Visiting: https://wikimediafoundation.org/support/benefactors/
# Depth: 0 - Visiting: https://www.councilofnonprofits.org/tools-resources/operating-reserves-nonprofits
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Resolution:Setting_Working_Capital_Reserve_Target
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Donor_privacy_policy
# Depth: 0 - Visiting: https://thankyou.wikipedia.org/wiki/Thank_You/en
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/Wikipedia:Why_create_an_account%3F
# Depth: 0 - Visiting: https://annual.wikimedia.org
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Wikimedia_Foundation_Annual_Plan
# Depth: 0 - Visiting: https://wikimediaendowment.org/
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/API
# Depth: 0 - Visiting: https://enterprise.wikimedia.com/
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Wikimedia_chapters
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Wikimedia_2030
# Depth: 0 - Visiting: https://2030.wikimedia.org
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/Help:Introduction
# Depth: 0 - Visiting: https://commons.wikimedia.org/wiki/Commons:First_steps/Uploading_files
# Depth: 0 - Visiting: https://twitter.com/wikimedia
# Depth: 0 - Visiting: https://www.facebook.com/wikimediafoundation
# Depth: 0 - Visiting: https://www.instagram.com/wikimediafoundation
# Depth: 0 - Visiting: https://twitter.com/wikipedia
# Depth: 0 - Visiting: https://www.facebook.com/wikipedia
# Depth: 0 - Visiting: https://www.instagram.com/wikipedia
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/New_Developers
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/Zendesk
# Depth: 0 - Visiting: https://www.zendesk.com/company/customers-partners/privacy-policy/
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.zendesk.com/company/customers-partners/master-subscription-agreement/#region-specific-terms
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=FAQ&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=Template:Support_Page_end&action=edit
# Depth: 0 - Visiting: https://donate.wikimedia.org/w/index.php?title=FAQ&oldid=37755
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Home
# Depth: 0 - Visiting: https://collab.wikimedia.org/wiki/Fundraising/Donatewiki_documentation
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:Privacy_policy
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:About
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:General_disclaimer
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/donate.wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Cookie_statement
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://donate.wikimedia.org/wiki/Special:LandingPage
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:MyLanguage/Ways_to_Give?utm_medium=donatewiki_nocountry
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:LandingPage
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Home
# Depth: 0 - Visiting: https://collab.wikimedia.org/wiki/Fundraising/Donatewiki_documentation
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:Privacy_policy
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:About
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Project:General_disclaimer
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/donate.wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Cookie_statement
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://foundation.wikimedia.org/wiki/Home
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://wikimediafoundation.org/news/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Answers
# Depth: 0 - Visiting: https://wikimediafoundation.org/participate/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/values/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/financial-reports/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Fundraising/Reports
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Contents
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/roles/board/
# Not Found
# Failed to get page
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Registered_user
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Help:User_page
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Help:Talk_page
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia:Translations
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:CreateAccount
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=Home&utm_medium=button&utm_campaign=C13_foundation.wikimedia.org?uselang=en
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/en:
# Depth: 0 - Visiting: https://wikimediafoundation.org/our-work/wikimedia-projects/
# Depth: 0 - Visiting: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=Home&utm_medium=pagelink&utm_campaign=C13_foundation.wikimedia.org?uselang=en
# Depth: 0 - Visiting: https://wikimediafoundation.org/participate/
# Depth: 0 - Visiting: https://www.wikipedia.org
# Depth: 0 - Visiting: https://www.wiktionary.org
# Depth: 0 - Visiting: https://www.wikinews.org
# Depth: 0 - Visiting: https://www.wikibooks.org
# Depth: 0 - Visiting: https://www.wikiquote.org
# Depth: 0 - Visiting: https://www.wikisource.org
# Depth: 0 - Visiting: https://www.wikiversity.org
# Depth: 0 - Visiting: https://www.wikivoyage.org
# Depth: 0 - Visiting: https://species.wikimedia.org
# Depth: 0 - Visiting: https://commons.wikimedia.org
# Depth: 0 - Visiting: https://www.wikidata.org
# Depth: 0 - Visiting: https://www.mediawiki.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Home&oldid=165302
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/foundation.wikimedia.org
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://collab.wikimedia.org/wiki/Fundraising/Donatewiki_documentation
# Depth: 0 - Visiting: https://collab.wikimedia.org/wiki/Special:Badtitle
# Not Found
# Failed to get page
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Privacy_policy
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/collab.wikimedia.org
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Cookie_statement
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://www.mediawiki.org/
# Depth: 1 - Visiting: https://foundation.wikimedia.org/wiki/Project:Privacy_policy
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://wikimediafoundation.org/news/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Answers
# Depth: 0 - Visiting: https://wikimediafoundation.org/participate/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/values/
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/financial-reports/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Fundraising/Reports
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Contents
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Special:Translate&group=agg-Privacy_Policy&filter=%21translated&action=page&language=
# Depth: 0 - Visiting: https://wikimediafoundation.org/role/board/
# Depth: 0 - Visiting: https://wikimediafoundation.org/our-work/wikimedia-projects/
# Depth: 0 - Visiting: https://shop.wikimedia.org
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Wikimedia_Cloud_Services
# Depth: 0 - Visiting: https://en.wikipedia.org/wiki/Main_Page
# Depth: 0 - Visiting: https://commons.wikimedia.org/wiki/Main_Page
# Depth: 0 - Visiting: https://en.wiktionary.org/wiki/Wiktionary:Main_Page
# Depth: 0 - Visiting: https://wikimediafoundation.org/
# Depth: 0 - Visiting: https://wikimediafoundation.org/our-work/wikimedia-projects/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_chapters
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_thematic_organizations
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_user_groups
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Grants:Start/About
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Projects
# Depth: 0 - Visiting: https://shop.wikimedia.org
# Depth: 0 - Visiting: https://labs.wikimedia.org
# Depth: 0 - Visiting: https://store.wikimedia.org/pages/copy-of-privacy-policy
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Wikimedia_Apps/Synced_Reading_Lists
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/CheckUser
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Stewards
# Depth: 0 - Visiting: https://www.mediawiki.org/wiki/Special:MyLanguage/Wikimedia_Cloud_Services
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Volunteer_Response_Team
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/IRC
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/Wikimedia_movement_affiliates
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Special:MyLanguage/CheckUser_policy
# Depth: 0 - Visiting: https://lists.wikimedia.org/mailman/listinfo/wikimediaannounce-l
# Depth: 0 - Visiting: https://lists.wikimedia.org/mailman/listinfo/wikimediaannounce-l
# Depth: 0 - Visiting: https://lists.wikimedia.org/mailman/listinfo/wikimediaannounce-l
# Depth: 0 - Visiting: https://wikimediafoundation.org/about/contact/
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/User:AKeton_(WMF)
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Template:Privacy_policy_navigation_2&action=edit
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Special:Translate/page-Template:Privacy_policy_navigation_2&language=en&action=page
# Depth: 0 - Visiting: https://meta.wikimedia.org/wiki/Access_to_nonpublic_personal_data_policy/Noticeboard
# Depth: 0 - Visiting: https://foundation.wikimedia.org/w/index.php?title=Policy:Privacy_policy&oldid=238682
# Depth: 0 - Visiting: https://creativecommons.org/licenses/by-sa/3.0/
# Depth: 0 - Visiting: https://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use
# Depth: 0 - Visiting: https://developer.wikimedia.org
# Depth: 0 - Visiting: https://stats.wikimedia.org/#/foundation.wikimedia.org
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-6f2571fd4462> in <cell line: 3>()
#       1 #Crawl the Wikipedia
#       2 crawler = Crawler()
# ----> 3 crawler.crawl("https://en.wikipedia.org/wiki/Main_Page", 3)
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      49             href = link.get('href')
#      50             if href and href.startswith('http'):
# ---> 51                 self.crawl(href, max_depth-1)
#      52
#      53 if __name__ == "__main__":
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      49             href = link.get('href')
#      50             if href and href.startswith('http'):
# ---> 51                 self.crawl(href, max_depth-1)
#      52
#      53 if __name__ == "__main__":
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      49             href = link.get('href')
#      50             if href and href.startswith('http'):
# ---> 51                 self.crawl(href, max_depth-1)
#      52
#      53 if __name__ == "__main__":
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      42             return
#      43         print(f'Depth: {max_depth} - Visiting: {url}')
# ---> 44         soup = self.get_soup(url)
#      45         if soup is None:
#      46             print("Failed to get page")
#
# <ipython-input-8-9f98ede16001> in get_soup(self, url)
#       9     def get_soup(self, url):
#      10         try:
# ---> 11             response = self.session.get(url, timeout=10)
#      12             if response.status_code == 200:
#      13                 html = response.content
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     540
#     541         kwargs.setdefault('allow_redirects', True)
# --> 542         return self.request('GET', url, **kwargs)
#     543
#     544     def options(self, url, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in connect(self)
#     361     def connect(self):
#     362         # Add certificate verification
# --> 363         self.sock = conn = self._new_conn()
#     364         hostname = self.host
#     365         tls_in_tls = False
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# /usr/local/lib/python3.10/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:

# %%
#Crawl Python Wevbsite
crawler = Crawler()
crawler.crawl("https://www.python.org", 1)
# Out:
# Depth: 1 - Visiting: https://www.python.org
# Depth: 0 - Visiting: https://www.python.org/psf/
# Depth: 0 - Visiting: https://docs.python.org
# Depth: 0 - Visiting: https://pypi.org/
# Depth: 0 - Visiting: https://psfmember.org/civicrm/contribute/transact?reset=1&id=2
# Depth: 0 - Visiting: https://www.facebook.com/pythonlang?fref=ts
# Depth: 0 - Visiting: https://twitter.com/ThePSF
# Depth: 0 - Visiting: http://brochure.getpython.info/
# Depth: 0 - Visiting: https://docs.python.org/3/license.html
# Depth: 0 - Visiting: https://wiki.python.org/moin/BeginnersGuide
# Depth: 0 - Visiting: https://devguide.python.org/
# Depth: 0 - Visiting: https://docs.python.org/faq/
# Depth: 0 - Visiting: http://wiki.python.org/moin/Languages
# Depth: 0 - Visiting: http://python.org/dev/peps/
# Depth: 0 - Visiting: https://wiki.python.org/moin/PythonBooks
# Depth: 0 - Visiting: https://wiki.python.org/moin/
# Depth: 0 - Visiting: http://pyfound.blogspot.com/
# Depth: 0 - Visiting: http://pycon.blogspot.com/
# Depth: 0 - Visiting: http://planetpython.org/
# Depth: 0 - Visiting: https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event
# Depth: 0 - Visiting: http://docs.python.org/3/tutorial/introduction.html#using-python-as-a-calculator
# Depth: 0 - Visiting: https://docs.python.org
# Depth: 0 - Visiting: https://blog.python.org
# Depth: 0 - Visiting: https://pyfound.blogspot.com/2023/05/the-python-language-summit-2023-towards.html
# Depth: 0 - Visiting: https://pyfound.blogspot.com/2023/05/the-python-language-summit-2023-burnout.html
# Depth: 0 - Visiting: https://pyfound.blogspot.com/2023/05/the-python-language-summit-2023-making.html
# Depth: 0 - Visiting: https://pyfound.blogspot.com/2023/05/the-python-language-summit-2023-three.html
# Depth: 0 - Visiting: https://pyfound.blogspot.com/2023/05/the-python-language-summit-2023-python.html
# Depth: 0 - Visiting: http://www.djangoproject.com/
# Depth: 0 - Visiting: http://www.pylonsproject.org/
# Depth: 0 - Visiting: http://bottlepy.org
# Depth: 0 - Visiting: http://tornadoweb.org
# Depth: 0 - Visiting: http://flask.pocoo.org/
# Depth: 0 - Visiting: http://www.web2py.com/
# Depth: 0 - Visiting: http://wiki.python.org/moin/TkInter
# Depth: 0 - Visiting: https://wiki.gnome.org/Projects/PyGObject
# Depth: 0 - Visiting: http://www.riverbankcomputing.co.uk/software/pyqt/intro
# Depth: 0 - Visiting: https://wiki.qt.io/PySide
# Depth: 0 - Visiting: https://kivy.org/
# Depth: 0 - Visiting: http://www.wxpython.org/
# Depth: 0 - Visiting: http://www.scipy.org
# Depth: 0 - Visiting: http://pandas.pydata.org/
# Depth: 0 - Visiting: http://ipython.org
# Depth: 0 - Visiting: http://buildbot.net/
# Depth: 0 - Visiting: http://trac.edgewall.org/
# Depth: 0 - Visiting: http://roundup.sourceforge.net/
# Depth: 0 - Visiting: http://www.ansible.com
# Depth: 0 - Visiting: https://saltproject.io
# Depth: 0 - Visiting: https://www.openstack.org
# Depth: 0 - Visiting: https://xon.sh
# Depth: 0 - Visiting: http://brochure.getpython.info/
# Depth: 0 - Visiting: https://docs.python.org/3/license.html
# Depth: 0 - Visiting: https://wiki.python.org/moin/BeginnersGuide
# Depth: 0 - Visiting: https://devguide.python.org/
# Depth: 0 - Visiting: https://docs.python.org/faq/
# Depth: 0 - Visiting: http://wiki.python.org/moin/Languages
# Depth: 0 - Visiting: http://python.org/dev/peps/
# Depth: 0 - Visiting: https://wiki.python.org/moin/PythonBooks
# Depth: 0 - Visiting: https://wiki.python.org/moin/
# Depth: 0 - Visiting: http://pyfound.blogspot.com/
# Depth: 0 - Visiting: http://pycon.blogspot.com/
# Depth: 0 - Visiting: http://planetpython.org/
# Depth: 0 - Visiting: https://wiki.python.org/moin/PythonEventsCalendar#Submitting_an_Event
# Depth: 0 - Visiting: https://devguide.python.org/
# Depth: 0 - Visiting: https://bugs.python.org/
# Depth: 0 - Visiting: https://mail.python.org/mailman/listinfo/python-dev
# Depth: 0 - Visiting: https://github.com/python/pythondotorg/issues
# Depth: 0 - Visiting: https://status.python.org/

# %%
#Crawl the New York Times website 
crawler = Crawler()
crawler.crawl("https://www.nytimes.com", 2)
# Out:
# Depth: 2 - Visiting: https://www.nytimes.com
# Depth: 1 - Visiting: https://www.nytimes.com/es/
# Forbidden
# Failed to get page
# Depth: 1 - Visiting: https://cn.nytimes.com
# Depth: 0 - Visiting: https://www.nytimes.com/
# Depth: 0 - Visiting: https://www.nytimes.com/es/
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/newsletters/chinese-briefing/
# Depth: 0 - Visiting: https://cn.nytimes.com/tools/r.html?url=/&langkey=zh-hans
# Depth: 0 - Visiting: https://cn.nytimes.com/tools/r.html?url=/zh-hant/&langkey=zh-hant
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/2023/05/25/world/asia/us-book-bans.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/2023/05/25/world/asia/us-book-bans.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/interactive/2023/02/16/chinese/china-covid-death-estimates-chinese.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/interactive/2023/02/16/chinese/china-covid-death-estimates-chinese.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/interactive/2023/travel/52-places-travel-2023-cn.html
# Depth: 0 - Visiting: https://www.nytimes.com/interactive/2023/travel/52-places-travel-2023-cn.html
# Depth: 0 - Visiting: https://cn.nytimes.com/interactive/20230120/top2022/top-stories.html
# Depth: 0 - Visiting: https://cn.nytimes.com/interactive/20230120/top2022/top-stories.html
# Depth: 0 - Visiting: https://cn.nytimes.com/interactive/20230120/top2022/top-oped.html
# Depth: 0 - Visiting: https://cn.nytimes.com/interactive/20230120/top2022/top-oped.html
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hant/interactive/2022/12/20/technology/china-protests-twitter-bots-elon-musk.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hant/interactive/2022/12/20/technology/china-protests-twitter-bots-elon-musk.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/2022/12/01/world/asia/china-protests-censorship-video.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/2022/12/01/world/asia/china-protests-censorship-video.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/interactive/2022/11/30/world/asia/china-protests-demands-cn.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/interactive/2022/11/30/world/asia/china-protests-demands-cn.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/2022/11/17/world/asia/china-zero-covid-policy-videos.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/2022/11/17/world/asia/china-zero-covid-policy-videos.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/interactive/2022/10/25/world/asia/xi-propaganda-chinese.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/interactive/2022/10/25/world/asia/xi-propaganda-chinese.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh/2022/10/06/world/asia/li-wenliang-chinese.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/zh/2022/10/06/world/asia/li-wenliang-chinese.html
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.shi-magazine.com/
# Depth: 0 - Visiting: https://www.nytimes.com/newsletters/chinese-briefing
# Depth: 0 - Visiting: https://www.nytimes.com/zh-hans/privacy/privacy-policy
# Depth: 0 - Visiting: https://itunes.apple.com/app/apple-store/id807498298?pt=13036&ct=news-hp&mt=8
# Depth: 0 - Visiting: https://play.google.com/store/apps/details?id=com.nytimes.cn
# Depth: 1 - Visiting: https://www.nytimes.com/section/todayspaper
# Depth: 0 - Visiting: https://www.nytimes.com/section/todayspaper
# Depth: 0 - Visiting: https://www.nytimes.com/section/todayspaper
# Depth: 0 - Visiting: https://help.nytimes.com/hc/en-us/articles/115014792127-Copyright-notice
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytco.com/
# Depth: 0 - Visiting: https://help.nytimes.com/hc/en-us/articles/115015385887-Contact-Us
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://help.nytimes.com/hc/en-us/articles/115015727108-Accessibility
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytco.com/careers/
# Depth: 0 - Visiting: https://nytmediakit.com/
# Depth: 0 - Visiting: https://www.tbrandstudio.com/
# Depth: 0 - Visiting: https://www.nytimes.com/privacy/cookie-policy#how-do-i-manage-trackers
# Depth: 0 - Visiting: https://www.nytimes.com/privacy/privacy-policy
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://help.nytimes.com/hc/en-us/articles/115014893428-Terms-of-service
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://help.nytimes.com/hc/en-us/articles/115014893968-Terms-of-sale
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/ca/?action=click&region=Footer&pgtype=Homepage
# Depth: 0 - Visiting: https://www.nytimes.com/international/?action=click&region=Footer&pgtype=Homepage
# Depth: 0 - Visiting: https://help.nytimes.com/hc/en-us
# Forbidden
# Failed to get page
# Depth: 0 - Visiting: https://www.nytimes.com/subscription?campaignId=37WXW
# Depth: 1 - Visiting: https://cooking.nytimes.com/
# Depth: 0 - Visiting: http://www.facebook.com/sharer/sharer.php?u=https://cooking.nytimes.com/recipes/1023145-tajin-grilled-chicken%3Fsmid=fb-share
# Depth: 0 - Visiting: http://www.pinterest.com/pin/create/button/?url=https%3A%2F%2Fcooking.nytimes.com%2Frecipes%2F1023145-tajin-grilled-chicken%3Fsmid=pin-share&description=NYT%20Cooking:%20Tajín%20Grilled%20Chicken&media=https%3A%2F%2Fstatic01.nyt.com%2Fimages%2F2022%2F05%2F25%2Fdining%2F25Memorial-tajin-grilled-chicken%2Fmerlin_206068182_ffd1a522-033b-4519-969f-1990ecb8a8f0-threeByTwoMediumAt2X.jpg
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-f5b98cacb230> in <cell line: 3>()
#       1 #Crawl the New York Times website
#       2 crawler = Crawler()
# ----> 3 crawler.crawl("https://www.nytimes.com", 2)
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      49             href = link.get('href')
#      50             if href and href.startswith('http'):
# ---> 51                 self.crawl(href, max_depth-1)
#      52
#      53 if __name__ == "__main__":
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      49             href = link.get('href')
#      50             if href and href.startswith('http'):
# ---> 51                 self.crawl(href, max_depth-1)
#      52
#      53 if __name__ == "__main__":
#
# <ipython-input-8-9f98ede16001> in crawl(self, url, max_depth)
#      42             return
#      43         print(f'Depth: {max_depth} - Visiting: {url}')
# ---> 44         soup = self.get_soup(url)
#      45         if soup is None:
#      46             print("Failed to get page")
#
# <ipython-input-8-9f98ede16001> in get_soup(self, url)
#      16                 if not os.path.exists('downloaded_pages'):
#      17                     os.makedirs('downloaded_pages')
# ---> 18                 with open(os.path.join('downloaded_pages', filename), 'wb') as f:
#      19                     f.write(html)
#      20                 return BeautifulSoup(html, 'html.parser')
#
# OSError: [Errno 36] File name too long: 'downloaded_pages/www.pinterest.com_pin_create_button_?url=https%3A%2F%2Fcooking.nytimes.com%2Frecipes%2F1023145-tajin-grilled-chicken%3Fsmid=pin-share&description=NYT%20Cooking:%20Tajín%20Grilled%20Chicken&media=https%3A%2F%2Fstatic01.nyt.com%2Fimages%2F2022%2F05%2F25%2Fdining%2F25Memorial-tajin-grilled-chicken%2Fmerlin_206068182_ffd1a522-033b-4519-969f-1990ecb8a8f0-threeByTwoMediumAt2X.jpg.html'

# %%
#Crawl the GitHub homepage
crawler = Crawler()
crawler.crawl("https://github.com", 1)
# Out:
# Depth: 1 - Visiting: https://github.com
# Depth: 0 - Visiting: https://github.com/
# Depth: 0 - Visiting: https://docs.github.com
# Depth: 0 - Visiting: https://skills.github.com/
# Depth: 0 - Visiting: https://github.blog
# Depth: 0 - Visiting: https://education.github.com
# Depth: 0 - Visiting: https://resources.github.com/devops/
# Depth: 0 - Visiting: https://resources.github.com/devops/fundamentals/devsecops/
# Depth: 0 - Visiting: https://resources.github.com/
# Depth: 0 - Visiting: https://github.com/features/security/code
# Depth: 0 - Visiting: https://resources.github.com/security/sast/
# Depth: 0 - Visiting: https://resources.github.com/newsletter/
# Depth: 0 - Visiting: https://resources.github.com
# Depth: 0 - Visiting: https://github.com/github/roadmap
# Depth: 0 - Visiting: https://docs.github.com
# Depth: 0 - Visiting: https://partner.github.com
# Depth: 0 - Visiting: https://www.electronjs.org
# Depth: 0 - Visiting: https://desktop.github.com/
# Depth: 0 - Visiting: https://docs.github.com
# Depth: 0 - Visiting: https://github.community
# Depth: 0 - Visiting: https://services.github.com/
# Depth: 0 - Visiting: https://skills.github.com/
# Depth: 0 - Visiting: https://www.githubstatus.com/
# Depth: 0 - Visiting: https://support.github.com?tags=dotcom-footer
# Depth: 0 - Visiting: https://github.com/about
# Depth: 0 - Visiting: https://github.blog
# Depth: 0 - Visiting: https://socialimpact.github.com/
# Depth: 0 - Visiting: https://shop.github.com
# Depth: 0 - Visiting: https://twitter.com/github
# Depth: 0 - Visiting: https://www.facebook.com/GitHub
# Depth: 0 - Visiting: https://www.linkedin.com/company/github
# Unexpected HTTP response: 999
# Failed to get page
# Depth: 0 - Visiting: https://www.youtube.com/github
# Depth: 0 - Visiting: https://www.twitch.tv/github
# Depth: 0 - Visiting: https://www.tiktok.com/@github
# Depth: 0 - Visiting: https://github.com/github
# Depth: 0 - Visiting: https://docs.github.com/site-policy/github-terms/github-terms-of-service
# Depth: 0 - Visiting: https://docs.github.com/site-policy/privacy-policies/github-privacy-statement
# Depth: 0 - Visiting: https://github.com/github/site-policy/pull/582
